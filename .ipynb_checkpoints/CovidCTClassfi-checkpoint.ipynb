# %% [markdown]
# # Predict Covid-19 with deep-learning
#
# *by: Stańdo Jacek

# %% [markdown]
# ## View data

# %%
from fastai.vision import *

np.random.seed(42)
path = r"E:\CTCovidData\data1"
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

print(data.classes,"Train images: ", len(data.train_ds)," Validation images: " ,len(data.valid_ds))

print(data.show_batch(rows=3, figsize=(7,8)))
# Out:
# ['covid', 'noncovid'] Train images:  497  Validation images:  124
# None

# %% [markdown]
# ## Train model

# %%
learn = cnn_learner(data, models.resnet50, metrics=[accuracy])
learn.lr_find()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.715293</td>
#       <td>0.230108</td>
#       <td>0.919355</td>
#       <td>02:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.551207</td>
#       <td>0.194098</td>
#       <td>0.927419</td>
#       <td>02:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.481444</td>
#       <td>0.740470</td>
#       <td>0.758065</td>
#       <td>02:48</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.431947</td>
#       <td>0.917739</td>
#       <td>0.717742</td>
#       <td>02:48</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='15', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       73.33% [11/15 28:13<10:15]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.220216</td>
#       <td>#na#</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.239322</td>
#       <td>#na#</td>
#       <td>02:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.213835</td>
#       <td>#na#</td>
#       <td>02:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.198780</td>
#       <td>#na#</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.186025</td>
#       <td>#na#</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.156194</td>
#       <td>#na#</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.127472</td>
#       <td>#na#</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.132278</td>
#       <td>#na#</td>
#       <td>02:35</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.209744</td>
#       <td>#na#</td>
#       <td>02:34</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.276439</td>
#       <td>#na#</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.403193</td>
#       <td>#na#</td>
#       <td>02:31</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.29% [1/7 00:39<03:55 0.4111]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
#Find best lr
learn.recorder.plot()

# %%
learn.fit_one_cycle(7, max_lr=1e-03)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.144644</td>
#       <td>17.062143</td>
#       <td>0.169355</td>
#       <td>02:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.130311</td>
#       <td>60.888222</td>
#       <td>0.169355</td>
#       <td>02:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.140656</td>
#       <td>120.352859</td>
#       <td>0.427419</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.184499</td>
#       <td>0.354356</td>
#       <td>0.919355</td>
#       <td>02:52</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.169033</td>
#       <td>0.589693</td>
#       <td>0.774194</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.143396</td>
#       <td>0.204374</td>
#       <td>0.975806</td>
#       <td>03:38</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.123859</td>
#       <td>0.131217</td>
#       <td>0.975806</td>
#       <td>03:30</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('resnet50')

# %% [markdown]
# ## Results

# %%
learn.load('resnet50');

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
